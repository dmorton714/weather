# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
import csv
import numpy as np

# %%
df = pd.read_csv (r'data.csv')



filename = 'data.csv'
with open('data.csv') as f:
    reader = csv.reader(f)
    header_row = next(reader)
#To display the headers to find correct vales to call min and max
print("This is the imported data.csv header", '\n' , header_row)
print("This is the total number of rows in the file:", '\n' ,len(df))


print("The Max Temp between 1948 to 2022 is :", df['Max'].max())
print("The Max Temp between 1948 to 2022 is :", df['Min'].min())




# This replaces the Nan values to 0 

df['Perc'] = df['Perc'].fillna(0)
print("This removed the NaN values in the Perc Column.", '\n', df.head(10))
# Out:
# This is the imported data.csv header
#  ['STATION ID', 'STATION NAME', 'Date', 'Avg', 'Max', 'Min', 'Perc']
# This is the total number of rows in the file:
#  27184
# The Max Temp between 1948 to 2022 is : 106.0
# The Max Temp between 1948 to 2022 is : -22.0
# This removed the NaN values in the Perc Column.
#      STATION ID                             STATION NAME   Date   Avg   Max  \
# 0  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  44.5  62.0
# 1  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  30.5  35.0
# 2  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  31.5  34.0
# 3  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  34.5  39.0
# 4  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  34.5  37.0
# 5  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  39.5  48.0
# 6  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  38.0  49.0
# 7  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  48.0  59.0
# 8  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  47.0  59.0
# 9  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  33.5  41.0
#
#     Min  Perc
# 0  27.0  1.28
# 1  26.0  0.00
# 2  29.0  0.00
# 3  30.0  0.00
# 4  32.0  0.00
# 5  31.0  0.00
# 6  27.0  0.00
# 7  37.0  0.00
# 8  35.0  0.00
# 9  26.0  0.00

# %%
#This shows the duplicates in the max temp as true or false in a new column 

df['is_duplicated'] = df.duplicated('Max')
df['is_duplicated'].sum()

print(df.head(20))
# Out:
#      STATION ID                             STATION NAME   Date   Avg   Max  \
# 0   USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  44.5  62.0
# 1   USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  30.5  35.0
# 2   USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  31.5  34.0
# 3   USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  34.5  39.0
# 4   USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  34.5  37.0
# 5   USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  39.5  48.0
# 6   USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  38.0  49.0
# 7   USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  48.0  59.0
# 8   USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  47.0  59.0
# 9   USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  33.5  41.0
# 10  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  34.0  46.0
# 11  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  39.0  44.0
# 12  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  26.0  36.0
# 13  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  13.0  18.0
# 14  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  24.0  40.0
# 15  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  27.0  36.0
# 16  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  15.0  22.0
# 17  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  12.0  21.0
# 18  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  20.0  33.0
# 19  USW00093821  LOUISVILLE INTERNATIONAL AIRPORT, KY US  11948  27.0  41.0
#
#      Min  Perc  is_duplicated
# 0   27.0  1.28          False
# 1   26.0  0.00          False
# 2   29.0  0.00          False
# 3   30.0  0.00          False
# 4   32.0  0.00          False
# 5   31.0  0.00          False
# 6   27.0  0.00          False
# 7   37.0  0.00          False
# 8   35.0  0.00           True
# 9   26.0  0.00          False
# 10  22.0  0.00          False
# 11  34.0  0.51          False
# 12  16.0  0.00          False
# 13   8.0  0.00          False
# 14   8.0  0.00          False
# 15  18.0  0.01           True
# 16   8.0  0.11          False
# 17   3.0  0.00          False
# 18   7.0  0.00          False
# 19  13.0  0.01           True

# %%
df = pd.read_csv (r'jan.csv')

filename = 'jan.csv'
with open('jan.csv') as f:
    reader = csv.reader(f)
    header_row = next(reader)
# print(header_row)



#col_list = ["fifties", "sixties"]
#print(df["fifties"])
#print(df["sixties"])
#avg works!!!!
#date works!!

# avgs = []
# for row in reader:
#     avg = float(row[2])
#     avgs.append(avg)
# print(avgs)

df2 = df['fifties'].mean()
print(df2)

df3 = df['sixties'].mean()
print(df3)

# df2.append([df2], [df3])

# df2 = df2.append(df3)
# print(df2)

df2 = df['seventies'].mean()
print(df2)

df2 = df['eighties'].mean()
print(df2)

df2 = df['nineties'].mean()
print(df2)

df2 = df['twok'].mean()
print(df2)

df2 = df['twenty ten'].mean()
print(df2)



decade = ["50's","60's", "70's", "80's", "90's", "00's", "10's"] 
jan = [35.85, 32.02, 30.40, 32.20, 35.90, 35.60, 34.45]

print(decade, '\n', jan)
# Out:
# 35.851612903225806
# 32.019354838709674
# 30.403225806451612
# 32.19516129032258
# 35.90483870967742
# 35.596774193548384
# 34.45322580645161
# ["50's", "60's", "70's", "80's", "90's", "00's", "10's"]
#  [35.85, 32.02, 30.4, 32.2, 35.9, 35.6, 34.45]

# %%
df = pd.read_csv (r'feb.csv')


filename = 'feb.csv'
with open('feb.csv') as f:
    reader = csv.reader(f)
    header_row = next(reader)
print(header_row)

df4 = df['fifties'].mean()
print(df4)

df4 = df['sixties'].mean()
print(df4)

df4 = df['seventies'].mean()
print(df4)

df4 = df['eighties'].mean()
print(df4)

df4 = df['nineties'].mean()
print(df4)

df4 = df['twok'].mean()
print(df4)

df4 = df['twenty ten'].mean()
print(df4)



decade = ["50's", "60's", "70's", "80's", "90's", "00's", "10's"] 
feb = [38.90, 34.31, 35.35, 36.29, 40.27, 38.52, 38.98]
print(decade, '\n', feb)
# Out:
# ['fifties', 'sixties', 'seventies', 'eighties', 'nineties', 'twok', 'twenty ten']
# 38.90070921985816
# 34.30742049469965
# 35.347517730496456
# 36.28975265017668
# 40.273049645390074
# 38.52120141342756
# 38.984042553191486
# ["50's", "60's", "70's", "80's", "90's", "00's", "10's"]
#  [38.9, 34.31, 35.35, 36.29, 40.27, 38.52, 38.98]

# %%
df = pd.read_csv (r'March.csv')


filename = 'March.csv'
with open('March.csv') as f:
    reader = csv.reader(f)
    header_row = next(reader)
print(header_row)

df4 = df['fifties'].mean()
print(df4)

df4 = df['sixties'].mean()
print(df4)

df4 = df['seventies'].mean()
print(df4)

df4 = df['eighties'].mean()
print(df4)

df4 = df['nineties'].mean()
print(df4)

df4 = df['twok'].mean()
print(df4)

df4 = df['twenty ten'].mean()
print(df4)

decade = ["50's" "60's" "70's" "80's" "90's" "00's" "10's"] 
march = [44.57, 43.83, 46.96, 46.24, 46.88, 48.38, 48.49]

# %%
df = pd.read_csv (r'april.csv')


filename = 'april.csv'
with open('april.csv') as f:
    reader = csv.reader(f)
    header_row = next(reader)
print(header_row)

df4 = df['fifties'].mean()
print(df4)

df4 = df['sixties'].mean()
print(df4)

df4 = df['seventies'].mean()
print(df4)

df4 = df['eighties'].mean()
print(df4)

df4 = df['nineties'].mean()
print(df4)

df4 = df['twok'].mean()
print(df4)

df4 = df['twenty ten'].mean()
print(df4)

decade = ["50's" "60's" "70's" "80's" "90's" "00's" "10's"] 
april = [56.72, 56.62, 56.69, 56.16, 56.81, 58.92, 60.20]

# %%
df = pd.read_csv (r'may.csv')


filename = 'may.csv'
with open('may.csv') as f:
    reader = csv.reader(f)
    header_row = next(reader)
print(header_row)

df4 = df['fifties'].mean()
print(df4)

df4 = df['sixties'].mean()
print(df4)

df4 = df['seventies'].mean()
print(df4)

df4 = df['eighties'].mean()
print(df4)

df4 = df['nineties'].mean()
print(df4)

df4 = df['twok'].mean()
print(df4)

df4 = df['twenty ten'].mean()
print(df4)

decade = ["50's" "60's" "70's" "80's" "90's" "00's" "10's"] 
may = [66.60, 64.86, 65.15, 65.92, 66.43, 67.16, 69.99]
# Out:
# ['fifties', 'sixties', 'seventies', 'eighties', 'nineties', 'twok', 'twenty ten']
# 66.59838709677419
# 64.85806451612903
# 65.15161290322581
# 65.91935483870968
# 66.43387096774194
# 67.16129032258064
# 69.98548387096774

# %%
df = pd.read_csv (r'june.csv')


filename = 'june.csv'
with open('june.csv') as f:
    reader = csv.reader(f)
    header_row = next(reader)
print(header_row)

df4 = df['fifties'].mean()
print(df4)

df4 = df['sixties'].mean()
print(df4)

df4 = df['seventies'].mean()
print(df4)

df4 = df['eighties'].mean()
print(df4)

df4 = df['nineties'].mean()
print(df4)

df4 = df['twok'].mean()
print(df4)

df4 = df['twenty ten'].mean()
print(df4)

decade = ["50's" "60's" "70's" "80's" "90's" "00's" "10's"] 
june = [75.04, 72.87, 73.58, 74.29, 75.02, 75.57, 77.44]
# Out:
# ['fifties', 'sixties', 'seventies', 'eighties', 'nineties', 'twok', 'twenty ten']
# 75.04
# 72.86666666666666
# 73.58166666666666
# 74.28833333333333
# 75.02166666666666
# 75.56833333333333
# 77.44166666666666

# %%
df = pd.read_csv (r'july.csv')


filename = 'july.csv'
with open('july.csv') as f:
    reader = csv.reader(f)
    header_row = next(reader)
print(header_row)

df4 = df['fifties'].mean()
print(df4)

df4 = df['sixties'].mean()
print(df4)

df4 = df['seventies'].mean()
print(df4)

df4 = df['eighties'].mean()
print(df4)

df4 = df['nineties'].mean()
print(df4)

df4 = df['twok'].mean()
print(df4)

df4 = df['twenty ten'].mean()
print(df4)

decades = ["50's" "60's" "70's" "80's" "90's" "00's" "10's"] 
july = [78.68, 76.62, 77.03, 78.94, 79.24, 78.15, 80.58]
# Out:
# ['fifties', 'sixties', 'seventies', 'eighties', 'nineties', 'twok', 'twenty ten']
# 78.6774193548387
# 76.61612903225806
# 77.02903225806452
# 78.94193548387096
# 79.23870967741935
# 78.15161290322581
# 80.58225806451613

# %%
df = pd.read_csv (r'aug.csv')


filename = 'aug.csv'
with open('aug.csv') as f:
    reader = csv.reader(f)
    header_row = next(reader)
print(header_row)

df4 = df['fifties'].mean()
print(df4)

df4 = df['sixties'].mean()
print(df4)

df4 = df['seventies'].mean()
print(df4)

df4 = df['eighties'].mean()
print(df4)

df4 = df['nineties'].mean()
print(df4)

df4 = df['twok'].mean()
print(df4)

df4 = df['twenty ten'].mean()
print(df4)

decades = ["50's" "60's" "70's" "80's" "90's" "00's" "10's"] 
aug = [77.02, 75.35, 76.20, 77.18, 77.18, 78.89, 79.05]
# Out:
# ['fifties', 'sixties', 'seventies', 'eighties', 'nineties', 'twok', 'twenty ten']
# 77.02258064516128
# 75.35483870967742
# 76.20322580645161
# 77.18387096774194
# 77.18064516129033
# 78.88709677419355
# 79.05483870967743

# %%
df = pd.read_csv (r'sept.csv')


filename = 'sept.csv'
with open('sept.csv') as f:
    reader = csv.reader(f)
    header_row = next(reader)
print(header_row)

df4 = df['fifties'].mean()
print(df4)

df4 = df['sixties'].mean()
print(df4)

df4 = df['seventies'].mean()
print(df4)

df4 = df['eighties'].mean()
print(df4)

df4 = df['nineties'].mean()
print(df4)

df4 = df['twok'].mean()
print(df4)

df4 = df['twenty ten'].mean()
print(df4)


decades = ["50's" "60's" "70's" "80's" "90's" "00's" "10's"] 
sept = [70.17, 68.44, 70.30, 69.91, 69.99, 71.37, 73.21]
# Out:
# ['fifties', 'sixties', 'seventies', 'eighties', 'nineties', 'twok', 'twenty ten']
# 70.165
# 68.44166666666666
# 70.30333333333333
# 69.90666666666667
# 69.99166666666666
# 71.36666666666666
# 73.21

# %%
df = pd.read_csv (r'oct.csv')


filename = 'oct.csv'
with open('oct.csv') as f:
    reader = csv.reader(f)
    header_row = next(reader)
print(header_row)

df4 = df['fifties'].mean()
print(df4)

df4 = df['sixties'].mean()
print(df4)

df4 = df['seventies'].mean()
print(df4)

df4 = df['eighties'].mean()
print(df4)

df4 = df['nineties'].mean()
print(df4)

df4 = df['twok'].mean()
print(df4)

df4 = df['twenty ten'].mean()
print(df4)


decades = ["50's" "60's" "70's" "80's" "90's" "00's" "10's"] 
oct = [58.46, 57.36, 57.58, 57.82, 59.19, 59.50, 60.96]
# Out:
# ['fifties', 'sixties', 'seventies', 'eighties', 'nineties', 'twok', 'twenty ten']
# 58.458064516129035
# 57.35806451612903
# 57.58225806451613
# 57.81612903225806
# 59.188709677419354
# 59.50483870967742
# 60.95967741935484

# %%
df = pd.read_csv (r'nov.csv')


filename = 'nov.csv'
with open('nov.csv') as f:
    reader = csv.reader(f)
    header_row = next(reader)
print(header_row)

df4 = df['fifties'].mean()
print(df4)

df4 = df['sixties'].mean()
print(df4)

df4 = df['seventies'].mean()
print(df4)

df4 = df['eighties'].mean()
print(df4)

df4 = df['nineties'].mean()
print(df4)

df4 = df['twok'].mean()
print(df4)

df4 = df['twenty ten'].mean()
print(df4)



decades = ["50's" "60's" "70's" "80's" "90's" "00's" "10's"] 
nov = [44.39, 45.91, 46.97, 47.89, 47.49, 49.13, 47.56]
# Out:
# ['fifties', 'sixties', 'seventies', 'eighties', 'nineties', 'twok', 'twenty ten']
# 44.391666666666666
# 45.913333333333334
# 46.965
# 47.888333333333335
# 47.49
# 49.13166666666667
# 47.55833333333333

# %%
df = pd.read_csv (r'dec.csv')


filename = 'dec.csv'
with open('dec.csv') as f:
    reader = csv.reader(f)
    header_row = next(reader)
print(header_row)

df4 = df['fifties'].mean()
print(df4)

df4 = df['sixties'].mean()
print(df4)

df4 = df['seventies'].mean()
print(df4)

df4 = df['eighties'].mean()
print(df4)

df4 = df['nineties'].mean()
print(df4)

df4 = df['twok'].mean()
print(df4)

df4 = df['twenty ten'].mean()
print(df4)

decades = ["50's" "60's" "70's" "80's" "90's" "00's" "10's"] 
dec = [37.39, 34.76, 38.57, 36.17, 39.39, 37.58, 40.97]
# Out:
# ['fifties', 'sixties', 'seventies', 'eighties', 'nineties', 'twok', 'twenty ten']
# 37.39032258064516
# 34.75806451612903
# 38.56774193548387
# 36.174193548387095
# 39.38870967741936
# 37.58387096774194
# 40.96612903225807

# %%
# x axis values 
x = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sept", "Oct", "Nov", "Dec", ]

# corresponding y axis values 
ys = {
  "50s": [35.85,  38.90, 44.57, 56.72, 66.60, 75.04, 78.68, 77.02, 70.17, 58.46, 44.39, 37.39],
  "60s": [34.45, 34.31, 43.83, 56.62, 64.86, 72.87, 76.62, 75.35, 68.44, 57.36, 45.91, 34.76],
  "70s": [30.4, 35.35, 46.96, 56.69, 65.15, 73.58, 77.03, 76.20, 70.30, 57.58, 46.97, 38.57],
  "80s": [32.2, 36.29, 46.24, 56.16, 65.92, 74.29, 78.94, 77.18, 69.91, 57.82, 47.89, 36.17],
  "90s": [35.9, 40.27, 46.88, 56.81, 66.43, 75.02, 79.24, 77.18, 69.99, 59.19, 47.49, 39.39],
  "00s": [35.6, 38.52, 48.38, 58.92, 67.16, 75.57, 78.15, 78.89, 71.37, 59.50, 49.13, 37.58],
  "10s": [34.45, 38.98, 48.49, 60.2, 69.99, 77.44, 80.58, 79.05, 73.21, 60.96, 47.56, 40.97],
} 
 
# plotting the points  
# plt.plot(x, y["five"], y["six"], y["seven"], y["eight"], y["nine"], y["twok"], y["ten"])
for y in ys:
  plt.plot(x, ys[y], label=y)
  print('For Decade: ', y, "   Values: ", ys[y])

# plt.plot(x, y["five"], "", label="50s")
# plt.plot(x, y["six"], "", label="60s")
# plt.plot(x, y["seven"], "", label="70s",)
# plt.plot(x, y["eight"], "", label="80s",)
# plt.plot(x, y["nine"], "", label="90s",)
# plt.plot(x, y["twok"], "", label="00s",)
# plt.plot(x, y["ten"], "", label="10s",)


plt.legend()

    
# naming the x axis 
plt.xlabel('Months')

# naming the y axis 
plt.ylabel('Temperature') 
   
# giving a title to my graph 
plt.title('Average Temputures by Decade') 
    
# function to show the plot 
plt.show()
# Out:
# For Decade:  50s    Values:  [35.85, 38.9, 44.57, 56.72, 66.6, 75.04, 78.68, 77.02, 70.17, 58.46, 44.39, 37.39]
# For Decade:  60s    Values:  [34.45, 34.31, 43.83, 56.62, 64.86, 72.87, 76.62, 75.35, 68.44, 57.36, 45.91, 34.76]
# For Decade:  70s    Values:  [30.4, 35.35, 46.96, 56.69, 65.15, 73.58, 77.03, 76.2, 70.3, 57.58, 46.97, 38.57]
# For Decade:  80s    Values:  [32.2, 36.29, 46.24, 56.16, 65.92, 74.29, 78.94, 77.18, 69.91, 57.82, 47.89, 36.17]
# For Decade:  90s    Values:  [35.9, 40.27, 46.88, 56.81, 66.43, 75.02, 79.24, 77.18, 69.99, 59.19, 47.49, 39.39]
# For Decade:  00s    Values:  [35.6, 38.52, 48.38, 58.92, 67.16, 75.57, 78.15, 78.89, 71.37, 59.5, 49.13, 37.58]
# For Decade:  10s    Values:  [34.45, 38.98, 48.49, 60.2, 69.99, 77.44, 80.58, 79.05, 73.21, 60.96, 47.56, 40.97]

# %%
# graph showing the hottest and coldest months of the year

# x axis values 
x = ["50's","60's", "70's", "80's", "90's", "00's", "10's"] 

# corresponding y axis values 
ys = {
    "Jan" : [35.85, 32.02, 30.40, 32.20, 35.90, 35.60, 34.45],
    "July" : [78.68, 76.62, 77.03, 78.94, 79.24, 78.15, 80.58],
} 
 

for y in ys:
  plt.plot(x, ys[y], label=y)
  print('For Month: ', y, "   Values: ", ys[y])

plt.legend()

    
# naming the x axis 
plt.xlabel('Months')

# naming the y axis 
plt.ylabel('Decades') 
   
# giving a title to my graph 
plt.title('Hottest & Coldest Months by Decade') 
    
# function to show the plot 
plt.show()
# Out:
# For Month:  Jan    Values:  [35.85, 32.02, 30.4, 32.2, 35.9, 35.6, 34.45]
# For Month:  July    Values:  [78.68, 76.62, 77.03, 78.94, 79.24, 78.15, 80.58]
